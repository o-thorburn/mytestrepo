# %%
# Building libraries
# !pip install openai
# !pip install tweepy
# !pip install tweepy --upgrade
import tweepy
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAADRyiwEAAAAAVyAignb%2BpcKAU5rCs%2BAI5Q45Vyk%3DIC8kWmSHu9dkNW8j2PGBs2DpSkMiKmBFkoE7S6WcaprBHhIfil')

# Import basic libraries
import numpy as np 
import pandas as pd 
# import visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 KB 2.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai: filename=openai-0.26.4-py3-none-any.whl size=67744 sha256=d1b4dfd065b17bd12bc127d3a775397c3d32ad16a0d2fa838b148d141696a732
#   Stored in directory: /root/.cache/pip/wheels/2b/d8/4e/268f029bd3277c1dd9e8781a0e0296e0a63822665bfa2429fc
# Successfully built openai
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import openai
openai.api_key = "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"

# %%
prompt = """
Decide what people's opinion about work place music to improve mental health

"""
response = openai.Completion.create(model="text-davinci-003",prompt = prompt, max_tokens=100,temperature=0)
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "text": "\n\nThe opinion on work place music to improve mental health is divided. Some people believe that it can be beneficial, as it can help to reduce stress and create a more positive work environment. Others argue that it can be distracting and can lead to decreased productivity. Ultimately, it is up to the individual to decide if work place music is right for them."
#     }
#   ],
#   "created": 1675157709,
#   "id": "cmpl-6ehKfavanG4suf9Ofz3uJSjnVjXpJ",
#   "model": "text-davinci-003",
#   "object": "text_completion",
#   "usage": {
#     "completion_tokens": 72,
#     "prompt_tokens": 16,
#     "total_tokens": 88
#   }
# }

# %%
# Build a class
class OVO:
  '''
  Class to represent
  '''
  key = 'my-api-key...'
  def __init__(self):
    self.name=''
    
  def get_sentiment(self,prompt): # Trailor opinions
    self.prompt = prompt
    chatgpt = openai.Completion.create(engine="text-davinci-003", prompt=prompt, max_tokens=1000)
    #print(chatgpt.choices[0]['text'])
    #print(type(chatgpt.choices[0]['text']))
    return chatgpt.choices[0]['text']

  def get_image(self, prompt): # Movie poster
    self.prompt = prompt
    response = openai.Image.create(prompt=prompt,n=1,size="1024x1024")
    image_url = response['data'][0]['url']
    return image_url

  def get_procon(self, prompt): # Movie plot
    self.prompt = prompt
    chatgpt = openai.Completion.create(engine="text-davinci-003", prompt=prompt, max_tokens=1000)
    return chatgpt.choices[0]['text']

  def get_review(self, prompt): # Movie reviews
    self.prompt = prompt
    chatgpt = openai.Completion.create(engine="text-davinci-003", prompt=prompt, max_tokens=1000)
    return chatgpt.choices[0]['text']

# %%
sentiment = OVO()
sentiment.get_sentiment("What are people's feelings about music in the workplace")
# Out:
# '\n\nThe feelings of people towards music in the workplace can vary greatly. Some may find it distracting while others might appreciate having background noise to aid in concentration. Many employers are now allowing music to be played in the workplace to aid in productivity and provide a more enjoyable work environment. Ultimately, how people feel about music in the workplace depends on their own personal preferences and experiences.'

# %%
sentiment = OVO()
sentiment.get_procon("What are the pros and cons about music in the workplace")
# Out:
# '?\n\nPros:\n\n• It can increase productivity and help reduce stress.\n• Helps employees stay focused and enhances creativity when used in moderation.\n• It can be used to energize the workplace during its down periods.\n• Increased morale and improved job satisfaction due to increased comfort in the workplace.\n\nCons:\n\n• It can be a distraction, leading to decreased productivity and focus.\n• It may lead to disagreements between employees since tastes in music can vary greatly.\n• It can be difficult to control the volume so loud music can be disruptive.\n• It can cause a lack of concentration and be counter-productive.'

# %%
sentiment = OVO()
sentiment.get_sentiment("How can music effect mental health")
# Out:
# '?\n\nMusic has been found to have many positive effects on mental health, including reducing stress and anxiety, improving mood, and increasing positive thinking. Music can also help manage difficult emotions and provide a safe outlet for processing and expressing emotions. Additionally, music can promote mindfulness, helping people become more aware of their thoughts and feelings. Music can also enhance focus and boost motivation, and is even used in some therapy settings to help people explore emotions.'

# %%
# insert data analysis here
