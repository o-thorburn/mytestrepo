# %%
# Web App

# !pip install -q streamlit
# !pip install pyngrok
# !pip install jedi>=0.10
# !ngrok authtoken 2L41HP5ti15RiWBBXdl8wDkoYL8_2AA2r7e9uZgAR5KpyTnmL
from pyngrok import ngrok 
public_url = ngrok.connect(port='8501')
public_url
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 42.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.0/239.0 KB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.0/184.0 KB 18.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.0/79.0 KB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 KB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# %%writefile streamlit_app.py 
import streamlit as st
import pandas as pd
import plotly.express as px
st.image('/content/OVOlogo.png')

st.write('#      **Music for Work**')  #st.title('Music for Work')
#st.image('./header.png')
# https://markdown-editor.github.io/   This will help build markdown
st.markdown('''
This is a dashboard with the ability to personalize a playlist based on mental health :brain:

Data source: [Kaggle](https://www.kaggle.com/datasets/timmate/avocado-prices-2020)
''')
st.subheader("Rate yourself on a scale of 1-10 for the following mental states and we'll curate a playlist")
musicstats = pd.read_csv('/content/mxmh_survey_results.csv')
st.slider('**Anxiety**', 0, 10)
st.slider('**Depression**', 0, 10)
st.slider('**Insomnia**', 0, 10)
st.slider('**OCD**', 0, 10)
st.subheader('What Genre do you like best?')
st.selectbox('Genre', ['Select a Ganre','Classical', 'Country', 'EDM', 'Folk', 'Gospel', 'Hip hop', 'Jazz', 'K pop', 'Latin', 'Lofi', 'Metal', 'Pop', 'R&B', 'Rap', 'Rock', 'Video game music'])
st.subheader('Recommended Playlist:')

st.text("1. ‘Let’s Go Crazy’ by Prince")
st.text("2. ‘Don’t Stop Me Now‘ by Queen")
st.text("3. ‘Dancing Queen’ by ABBA ")
st.text("4. ‘Good Vibrations’ by The Beach Boys")
st.text("5. ‘The Way You Make Me Feel’ by Michael Jackson")
st.text("...")


st.header('Summary statistics')
st.image('/content/productivity.png')
# Out:
# Overwriting streamlit_app.py

# %%
# !streamlit run /content/streamlit_app.py & npx localtunnel --port 8501
# Out:
# npx: installed 22 in 2.331s
#
# ...
#
# your url is: https://dull-showers-sniff-34-80-8-150.loca.lt
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.80.8.150:8501
